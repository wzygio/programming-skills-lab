# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
DataPath='./run_time'
time = pd.read_csv(DataPath, header=None, engine='python')
time_ms = time/1000

# %%
figure = plt.figure(figsize=(8,5))
plt.plot(time_ms)
plt.xlabel("Map Length")
plt.ylabel("Run Time(ms)")
plt.show()

# %%
for i in range(1,41)
    time_complexity[i] = time_ms[0] * i^2
