# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
DataPath='./run_time'
time = pd.read_csv(DataPath, header=None, engine='python')
runtime = time.copy()
runtime = runtime/1000

# %%
figure = plt.figure(figsize=(8,5))
plt.plot(4*runtime)
plt.plot(time_c)
plt.xlabel("Map Length")
plt.ylabel("Run Time(ms)")
plt.legend(["Actual running time","Theoretical running time"])
plt.show()

# %%
unitime = runtime.iloc[1,0] - runtime.iloc[0,0]
time_c = [unitime*i*i for i in range(1,201)]

# %%
figure = plt.figure(figsize=(8,5))
plt.plot(runtime)
plt.xlabel("Map Length")
plt.ylabel("Run Time(ms)")
plt.show()

# %%
space = [4*i*i for i in range(1,501)]

# %%
figure = plt.figure(figsize=(8,5))
plt.plot(space)
plt.xlabel("Map Length",fontsize=15)
plt.ylabel("Space(bytes)",fontsize=15)
plt.show()
